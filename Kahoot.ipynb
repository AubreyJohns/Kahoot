# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Import dataset

# %%
header_list = ["Points", "Bonuses", "Accuracy", "Speed"]
df = pd.read_csv('kahoot_small.csv', header=None, skiprows=1, names=header_list, low_memory=False)
df.head()
# Out:
#    Points  Bonuses  Accuracy  Speed
# 0   10749      900        14   15.9
# 1    7966      300        10   16.1
# 2   12371     1600        14   11.3
# 3   11136      800        14   16.9
# 4   11783     1100        14   13.8

# %%
# Scatter plot

# %%
sns.lmplot(x='Bonuses', y='Points', data=df)

# %%
sns.lmplot(x='Accuracy', y='Points', data=df)

# %%
sns.lmplot(x='Speed', y='Points', data=df)

# %%
# Calculate correlations
corr = df.corr()

# Heatmap
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>
